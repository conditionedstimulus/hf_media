# %%
# !pip uninstall transformers
# Out:
# Found existing installation: transformers 4.44.2
# Uninstalling transformers-4.44.2:
#   Would remove:
#     /usr/local/bin/transformers-cli
#     /usr/local/lib/python3.10/dist-packages/transformers-4.44.2.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/transformers/*
# Proceed (Y/n)? Y
#   Successfully uninstalled transformers-4.44.2

# %%
# !pip install git+https://github.com/conditionedstimulus/transformers.git@add_dab_detr
# Out:
# Collecting git+https://github.com/conditionedstimulus/transformers.git@add_dab_detr
#   Cloning https://github.com/conditionedstimulus/transformers.git (to revision add_dab_detr) to /tmp/pip-req-build-r0dmx4qw
#   Running command git clone --filter=blob:none --quiet https://github.com/conditionedstimulus/transformers.git /tmp/pip-req-build-r0dmx4qw
#   Running command git checkout -b add_dab_detr --track origin/add_dab_detr
#   Switched to a new branch 'add_dab_detr'
#   Branch 'add_dab_detr' set up to track remote branch 'add_dab_detr' from 'origin'.
#   Resolved https://github.com/conditionedstimulus/transformers.git to commit b3bf25eb33cdfb288ad68126cc1e32e5ea2cbf44
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.0.dev0)
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0.dev0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (2024.8.30)
# Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 31.1 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.46.0.dev0-py3-none-any.whl size=9969790 sha256=f0676ceedc2d7482c0ed1975f94dbd513c652cb8827b26a67d3ccdb581ed740b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-waroiz4u/wheels/74/39/7a/851a8e5f8ef4684532357510278e6eedcc8ff77c4639e7f632
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
# Successfully installed tokenizers-0.20.0 transformers-4.46.0.dev0

# %%
# !pip install -q timm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 40.0 MB/s eta 0:00:00

# %%
from transformers import AutoModelForObjectDetection

checkpoint = "davidhajdu/dab-detr-resnet-50"

id2label = {0: "cat", 1: "dog"}
label2id = {v: k for k, v in id2label.items()}

model = AutoModelForObjectDetection.from_pretrained(
   checkpoint,
   id2label=id2label,
   label2id=label2id,
   ignore_mismatched_sizes=True,
)

print(model)
# Out:
# config.json:   0%|          | 0.00/5.00k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/175M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# Some weights of DABDETRForObjectDetection were not initialized from the model checkpoint at davidhajdu/dab-detr-resnet-50 and are newly initialized because the shapes did not match:
# - class_embed.bias: found shape torch.Size([91]) in the checkpoint and torch.Size([2]) in the model instantiated
# - class_embed.weight: found shape torch.Size([91, 256]) in the checkpoint and torch.Size([2, 256]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DABDETRForObjectDetection(
#   (model): DABDETRModel(
#     (query_refpoint_embeddings): Embedding(300, 4)
#     (input_projection): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (backbone): DABDETRConvModel(
#       (conv_encoder): DABDETRConvEncoder(
#         (model): TimmBackbone(
#           (_backbone): FeatureListNet(
#             (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#             (bn1): DABDETRFrozenBatchNorm2d()
#             (act1): ReLU(inplace=True)
#             (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#             (layer1): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): DABDETRFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer2): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DABDETRFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (3): Bottleneck(
#                 (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer3): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DABDETRFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (3): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (4): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (5): Bottleneck(
#                 (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#             (layer4): Sequential(
#               (0): Bottleneck(
#                 (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#                 (downsample): Sequential(
#                   (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                   (1): DABDETRFrozenBatchNorm2d()
#                 )
#               )
#               (1): Bottleneck(
#                 (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#               (2): Bottleneck(
#                 (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn1): DABDETRFrozenBatchNorm2d()
#                 (act1): ReLU(inplace=True)
#                 (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn2): DABDETRFrozenBatchNorm2d()
#                 (drop_block): Identity()
#                 (act2): ReLU(inplace=True)
#                 (aa): Identity()
#                 (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn3): DABDETRFrozenBatchNorm2d()
#                 (act3): ReLU(inplace=True)
#               )
#             )
#           )
#         )
#       )
#       (position_embedding): DABDETRSinePositionEmbedding()
#     )
#     (encoder): DABDETREncoder(
#       (query_scale): DABDETRMLP(
#         (layers): ModuleList(
#           (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (layers): ModuleList(
#         (0-5): 6 x DABDETREncoderLayer(
#           (self_attn): DetrAttention(
#             (k_proj): Linear(in_features=256, out_features=256, bias=True)
#             (v_proj): Linear(in_features=256, out_features=256, bias=True)
#             (q_proj): Linear(in_features=256, out_features=256, bias=True)
#             (out_proj): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): PReLU(num_parameters=1)
#           (fc1): Linear(in_features=256, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=256, bias=True)
#           (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (decoder): DABDETRDecoder(
#       (layers): ModuleList(
#         (0): DABDETRDecoderLayer(
#           (self_attn_query_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_query_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_key_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_key_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_value_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn): DABDETRAttention(
#             (output_projection): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_query_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_query_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_key_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_key_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_value_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_query_pos_sine_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn): DABDETRAttention(
#             (output_projection): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (cross_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=256, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=256, bias=True)
#           (activation_fn): PReLU(num_parameters=1)
#         )
#         (1-5): 5 x DABDETRDecoderLayer(
#           (self_attn_query_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_query_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_key_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_key_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn_value_proj): Linear(in_features=256, out_features=256, bias=True)
#           (self_attn): DABDETRAttention(
#             (output_projection): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (cross_attn_query_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_query_pos_proj): None
#           (cross_attn_key_content_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_key_pos_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_value_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn_query_pos_sine_proj): Linear(in_features=256, out_features=256, bias=True)
#           (cross_attn): DABDETRAttention(
#             (output_projection): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (cross_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=256, out_features=2048, bias=True)
#           (fc2): Linear(in_features=2048, out_features=256, bias=True)
#           (activation_fn): PReLU(num_parameters=1)
#         )
#       )
#       (layernorm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (query_scale): DABDETRMLP(
#         (layers): ModuleList(
#           (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (ref_point_head): DABDETRMLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (ref_anchor_head): DABDETRMLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=256, out_features=256, bias=True)
#           (1): Linear(in_features=256, out_features=2, bias=True)
#         )
#       )
#       (bbox_embed): DABDETRMLP(
#         (layers): ModuleList(
#           (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#           (2): Linear(in_features=256, out_features=4, bias=True)
#         )
#       )
#     )
#   )
#   (class_embed): Linear(in_features=256, out_features=2, bias=True)
#   (bbox_predictor): DABDETRMLP(
#     (layers): ModuleList(
#       (0-1): 2 x Linear(in_features=256, out_features=256, bias=True)
#       (2): Linear(in_features=256, out_features=4, bias=True)
#     )
#   )
# )
